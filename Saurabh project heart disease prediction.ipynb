# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
data = pd.read_csv("C:/Users/SAURABH/Downloads/heart.csv")
data.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
backup_data=data.copy()

# %%
data.shape
# Out:
# (918, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# # Finding Outliers in dataset

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# # Column Data Exploration

# %%
data["Age"].unique()
# Out:
# array([40, 49, 37, 48, 54, 39, 45, 58, 42, 38, 43, 60, 36, 44, 53, 52, 51,
#        56, 41, 32, 65, 35, 59, 50, 47, 31, 46, 57, 55, 63, 66, 34, 33, 61,
#        29, 62, 28, 30, 74, 68, 72, 64, 69, 67, 73, 70, 77, 75, 76, 71],
#       dtype=int64)

# %%
data["Age"].value_counts()
# Out:
# Age
# 54    51
# 58    42
# 55    41
# 56    38
# 57    38
# 52    36
# 51    35
# 59    35
# 62    35
# 53    33
# 60    32
# 48    31
# 61    31
# 63    30
# 50    25
# 46    24
# 41    24
# 43    24
# 64    22
# 65    21
# 49    21
# 47    19
# 44    19
# 42    18
# 45    18
# 38    16
# 67    15
# 39    15
# 66    13
# 69    13
# 40    13
# 35    11
# 37    11
# 68    10
# 34     7
# 74     7
# 70     7
# 36     6
# 71     5
# 32     5
# 72     4
# 29     3
# 75     3
# 33     2
# 77     2
# 76     2
# 31     2
# 30     1
# 28     1
# 73     1
# Name: count, dtype: int64

# %%
data["Sex"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data["Sex"].value_counts()
# Out:
# Sex
# M    725
# F    193
# Name: count, dtype: int64

# %%
data["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
data["ChestPainType"].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
# TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]

# %%
data["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
data["RestingECG"].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
data["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
data["ST_Slope"].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
data["HeartDisease"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data["HeartDisease"].value_counts()        # 0 ---> not have heart disease
                                           # 1 ---> have heart disease
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %% [markdown]
# # Finding Outliers in each columns  & Removing them

# %%
sns.boxplot(data=data["RestingBP"])
# Out:
# <Axes: >

# %%
sns.boxplot(y="RestingBP",data=data)
# Out:
# <Axes: ylabel='RestingBP'>

# %%
data["RestingBP"].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164], dtype=int64)

# %%
data["RestingBP"].value_counts()
# Out:
# RestingBP
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 185      1
# 98       1
# 92       1
# 113      1
# 164      1
# Name: count, Length: 67, dtype: int64

# %%
data["RestingBP"].quantile(0.97)
# Out:
# 170.0

# %%
data.shape
# Out:
# (918, 12)

# %%
data=data[data["RestingBP"]<data["RestingBP"].quantile(0.97)]

# %%
data["RestingBP"].quantile(0.002)
# Out:
# 89.048

# %%
data=data[data["RestingBP"]>data["RestingBP"].quantile(0.002)]

# %%
data.shape
# Out:
# (876, 12)

# %%
sns.boxplot(y="RestingBP",data=data)
# Out:
# <Axes: ylabel='RestingBP'>

# %%
data["RestingBP"].value_counts()
# Out:
# RestingBP
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
# 160     50
# 125     29
# 135     20
# 115     19
# 128     18
# 145     18
# 132     17
# 138     17
# 100     15
# 112     14
# 136     13
# 124     12
# 122     12
# 134     11
# 142     11
# 118     10
# 105      9
# 155      8
# 144      8
# 108      7
# 152      7
# 126      7
# 95       6
# 133      6
# 139      5
# 137      5
# 146      4
# 131      4
# 158      4
# 106      3
# 104      3
# 141      3
# 102      3
# 154      3
# 116      2
# 148      2
# 165      2
# 123      2
# 143      2
# 156      2
# 114      2
# 94       2
# 101      1
# 129      1
# 117      1
# 96       1
# 127      1
# 98       1
# 92       1
# 113      1
# 164      1
# Name: count, dtype: int64

# %%
sns.boxplot(y="Cholesterol",data=data)
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
data["Cholesterol"].describe()
# Out:
# count    876.000000
# mean     198.644977
# std      108.722171
# min        0.000000
# 25%      173.000000
# 50%      222.000000
# 75%      266.000000
# max      603.000000
# Name: Cholesterol, dtype: float64

# %%
data["Cholesterol"].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 291, 229, 307, 210, 329, 263, 147,  85,
#        269, 275, 179, 392, 466, 129, 255, 276, 282, 338, 160, 156, 272,
#        240, 161, 228, 292, 241, 166, 247, 331, 341, 243, 279, 198, 249,
#        168, 603, 159, 190, 185, 290, 212, 231, 222, 235, 320, 187, 266,
#        287, 404, 312, 251, 328, 192, 193, 308, 219, 257, 132, 226, 280,
#        217, 303, 298, 256, 117, 295, 173, 315, 281, 309, 200, 336, 355,
#        326, 171, 491, 271, 274, 394, 221, 126, 305, 220, 242, 344, 358,
#        169, 181,   0, 236, 203, 153, 316, 311, 252, 458, 384, 258, 349,
# ...

# %%
data["Cholesterol"].value_counts()
# Out:
# Cholesterol
# 0      162
# 254     11
# 220     10
# 223      9
# 230      9
#       ...
# 365      1
# 491      1
# 412      1
# 326      1
# 131      1
# Name: count, Length: 217, dtype: int64

# %%
"""lower_quantile = data['Cholesterol'].quantile(0.25)
upper_quantile = data['Cholesterol'].quantile(0.75)

threshold = 1.5

lower_bound = lower_quantile - threshold * (upper_quantile - lower_quantile)
upper_bound = upper_quantile + threshold * (upper_quantile - lower_quantile)

outliers = data[(data['Cholesterol'] < lower_bound) | (data['Cholesterol'] > upper_bound)]
mean_value = data['Cholesterol'].mean()

data.loc[outliers.index, 'Cholesterol'] = mean_value"""
# Out:
# "lower_quantile = data['Cholesterol'].quantile(0.25)\nupper_quantile = data['Cholesterol'].quantile(0.75)\n\nthreshold = 1.5\n\nlower_bound = lower_quantile - threshold * (upper_quantile - lower_quantile)\nupper_bound = upper_quantile + threshold * (upper_quantile - lower_quantile)\n\noutliers = data[(data['Cholesterol'] < lower_bound) | (data['Cholesterol'] > upper_bound)]\nmean_value = data['Cholesterol'].mean()\n\ndata.loc[outliers.index, 'Cholesterol'] = mean_value"

# %%
"""data = data[data["Cholesterol"]<352]
data = data[data["Cholesterol"]>105]"""
# Out:
# 'data = data[data["Cholesterol"]<352]\ndata = data[data["Cholesterol"]>105]'

# %%
from scipy.stats.mstats import winsorize

# %%
# data = data[data["Cholesterol"]!=0]

# %%
mean_cholesterol = data['Cholesterol'].mean()
data.loc[data['Cholesterol'] == 0, 'Cholesterol'] = mean_cholesterol

# %%
data['Cholesterol'] = winsorize(data['Cholesterol'], limits=[0.05, 0.05])

# %%
sns.boxplot(y="Cholesterol",data=data)
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
data["Cholesterol"].unique()
# Out:
# array([289.        , 180.        , 283.        , 214.        ,
#        195.        , 331.        , 237.        , 208.        ,
#        207.        , 284.        , 211.        , 167.        ,
#        204.        , 234.        , 273.        , 196.        ,
#        201.        , 248.        , 267.        , 223.        ,
#        184.        , 288.        , 215.        , 209.        ,
#        260.        , 188.        , 224.        , 172.        ,
#        186.        , 254.        , 306.        , 250.        ,
#        177.        , 227.        , 230.        , 294.        ,
#        264.        , 259.        , 175.        , 318.        ,
#        216.        , 233.        , 205.        , 245.        ,
#        194.        , 270.        , 213.        , 253.        ,
#        277.        , 202.        , 297.        , 225.        ,
#        246.        , 265.        , 182.        , 218.        ,
#        268.        , 206.        , 238.        , 291.        ,
# ...

# %%
data["Cholesterol"].describe()
# Out:
# C:\Users\SAURABH\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# count    876.000000
# mean     233.596446
# std       45.184115
# min      167.000000
# 25%      198.644977
# 50%      222.000000
# 75%      266.000000
# max      331.000000
# Name: Cholesterol, dtype: float64

# %%
sns.boxplot(y="Cholesterol",data=data)
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
data.shape
# Out:
# (876, 12)

# %%
data["Cholesterol"].describe()
# Out:
# C:\Users\SAURABH\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4737: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# count    876.000000
# mean     233.596446
# std       45.184115
# min      167.000000
# 25%      198.644977
# 50%      222.000000
# 75%      266.000000
# max      331.000000
# Name: Cholesterol, dtype: float64

# %%
sns.boxplot(data=data["FastingBS"])
# Out:
# <Axes: >

# %%
data["FastingBS"].describe()
# Out:
# count    876.000000
# mean       0.229452
# std        0.420721
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: FastingBS, dtype: float64

# %%
data["FastingBS"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data["FastingBS"].value_counts()
# Out:
# FastingBS
# 0    675
# 1    201
# Name: count, dtype: int64

# %%
sns.boxplot(data=data["FastingBS"])
# Out:
# <Axes: >

# %%
sns.boxplot(data=data["MaxHR"])
# Out:
# <Axes: >

# %%
data["MaxHR"].unique()
# Out:
# array([172, 156,  98, 108, 122, 170, 142, 130, 120,  99, 145, 140, 137,
#        150, 166, 165, 125, 160, 164, 138, 178, 112, 118, 127, 114, 154,
#        155,  87, 148, 100, 168, 184, 121, 153, 134,  96, 174, 175, 144,
#         82, 135, 115, 128, 116,  94, 110,  92, 180, 152, 124, 185, 139,
#        190, 146, 158, 132, 176, 119, 188, 162, 105,  90, 136, 167, 129,
#        102, 143, 103,  91,  93, 131, 149, 123, 126, 182,  77, 109, 133,
#        179, 113, 104,  95,  72,  97, 117,  86,  63, 157,  83,  60, 163,
#         67,  78, 141, 106, 111,  80,  84, 107, 161,  69,  88, 159, 151,
#        181, 186, 177, 173, 169, 171, 147,  71, 192, 194, 187, 202],
#       dtype=int64)

# %%
data["MaxHR"].describe()
# Out:
# count    876.000000
# mean     137.067352
# std       25.374071
# min       60.000000
# 25%      120.000000
# 50%      138.000000
# 75%      156.000000
# max      202.000000
# Name: MaxHR, dtype: float64

# %%
data = data[data["MaxHR"]>66]

# %%
sns.boxplot(data=data["MaxHR"])
# Out:
# <Axes: >

# %%
data.shape
# Out:
# (874, 12)

# %%
sns.boxplot(data=data["Oldpeak"])
# Out:
# <Axes: >

# %%
data["Oldpeak"].value_counts()
# Out:
# Oldpeak
#  0.0    353
#  1.0     83
#  2.0     70
#  1.5     48
#  3.0     27
#  1.2     26
#  0.2     21
#  1.4     18
#  0.5     17
#  1.8     17
#  1.6     15
#  0.8     14
#  0.1     14
#  2.5     14
#  0.6     13
#  0.4     11
#  0.3     11
#  1.9      7
#  1.1      7
#  0.7      7
#  1.3      7
#  4.0      7
#  2.6      7
#  2.8      6
#  1.7      6
#  2.2      5
#  0.9      4
#  3.6      4
#  2.4      4
#  3.5      2
#  2.3      2
#  3.2      2
# -0.5      2
# -0.1      2
#  2.1      2
# -1.0      2
# -0.8      1
#  4.4      1
#  6.2      1
#  2.9      1
#  4.2      1
#  3.8      1
#  5.6      1
#  5.0      1
# -0.9      1
#  3.7      1
#  3.1      1
# -2.6      1
# -1.5      1
# -2.0      1
# -1.1      1
# -0.7      1
#  3.4      1
# Name: count, dtype: int64

# %%
data["Oldpeak"].describe()
# Out:
# count    874.000000
# mean       0.871053
# std        1.056143
# min       -2.600000
# 25%        0.000000
# 50%        0.500000
# 75%        1.500000
# max        6.200000
# Name: Oldpeak, dtype: float64

# %%
data["Oldpeak"].quantile(0.987)
# Out:
# 3.930199999999991

# %%
data = data[data["Oldpeak"]<data["Oldpeak"].quantile(0.987)]

# %%
sns.boxplot(data=data["Oldpeak"])
# Out:
# <Axes: >

# %%
data["Oldpeak"].describe()
# Out:
# count    862.000000
# mean       0.821230
# std        0.970985
# min       -2.600000
# 25%        0.000000
# 50%        0.500000
# 75%        1.500000
# max        3.800000
# Name: Oldpeak, dtype: float64

# %%
data = data[data["Oldpeak"]!=-2.600000]
data = data[data["Oldpeak"]!=3.800000]

# %%
sns.boxplot(data=data["Oldpeak"])
# Out:
# <Axes: >

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >

# %% [markdown]
# # Data Analysis and Visualization

# %%
data.shape
# Out:
# (860, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 860 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             860 non-null    int64
#  1   Sex             860 non-null    object
#  2   ChestPainType   860 non-null    object
#  3   RestingBP       860 non-null    int64
#  4   Cholesterol     860 non-null    float64
#  5   FastingBS       860 non-null    int64
#  6   RestingECG      860 non-null    object
#  7   MaxHR           860 non-null    int64
#  8   ExerciseAngina  860 non-null    object
#  9   Oldpeak         860 non-null    float64
#  10  ST_Slope        860 non-null    object
#  11  HeartDisease    860 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 119.6+ KB

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             860 non-null    int64
#  1   Sex             860 non-null    object
#  2   ChestPainType   860 non-null    object
#  3   RestingBP       860 non-null    int64
#  4   Cholesterol     860 non-null    float64
#  5   FastingBS       860 non-null    int64
#  6   RestingECG      860 non-null    object
#  7   MaxHR           860 non-null    int64
#  8   ExerciseAngina  860 non-null    object
#  9   Oldpeak         860 non-null    float64
#  10  ST_Slope        860 non-null    object
#  11  HeartDisease    860 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 80.8+ KB

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  860.000000  860.000000   860.000000  860.000000  860.000000
# mean    53.266279  130.386047   233.427385    0.231395  137.311628
# std      9.472835   15.147311    45.138610    0.421970   25.170073
# min     28.000000   92.000000   167.000000    0.000000   67.000000
# 25%     47.000000  120.000000   198.644977    0.000000  120.000000
# 50%     54.000000  130.000000   222.000000    0.000000  138.000000
# 75%     60.000000  140.000000   265.250000    0.000000  156.000000
# max     77.000000  165.000000   331.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  860.000000    860.000000
# mean     0.821744      0.538372
# std      0.959714      0.498816
# min     -2.000000      0.000000
# 25%      0.000000      0.000000
# 50%      0.500000      1.000000
# 75%      1.500000      1.000000
# max      3.700000      1.000000

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140        289.0          0     Normal    172
# 1   49   F           NAP        160        180.0          0     Normal    156
# 2   37   M           ATA        130        283.0          0         ST     98
# 3   48   F           ASY        138        214.0          0     Normal    108
# 4   54   M           NAP        150        195.0          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 855   45   M            TA        110        264.0          0     Normal
# 856   68   M           ASY        144        193.0          1     Normal
# 857   57   M           ASY        130        167.0          0     Normal
# 858   57   F           ATA        130        236.0          0        LVH
# 859   38   M           NAP        138        175.0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 855    132              N      1.2     Flat             1
# 856    141              N      3.4     Flat             1
# 857    115              Y      1.2     Flat             1
# 858    174              N      0.0     Flat             1
# 859    173              N      0.0       Up             0

# %%
data.groupby("Age").sum("RestingBP")
# Out:
#      RestingBP   Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# Age
# 28         130    167.000000          0    185      0.0             0
# 29         390    710.000000          0    532      0.0             0
# 31         220    489.000000          0    303      1.5             1
# 32         553   1206.644977          1    761      0.7             2
# 33         220    544.000000          0    335      1.0             1
# 34         869   1358.644977          1   1208      0.9             2
# 35        1389   2383.644977          1   1748      4.1             4
# 36         742   1339.644977          1    999      5.0             2
# 37        1398   2571.000000          0   1682      6.0             1
# 38        1800   3354.869863          3   2206      7.4            10
# 39        1720   3359.000000          1   2156      4.2             2
# 40        1668   3183.289954          3   1959      6.4             6
# ...

# %%
plt.scatter(data['Age'], data['RestingBP'])
plt.xlabel('Age')
plt.ylabel('Resting Blood Pressure')
plt.title('Relationship between Age and Resting Blood Pressure')
plt.show()

# %%
plt.hist(data['Cholesterol'], bins=10)
plt.xlabel('Cholesterol')
plt.ylabel('Count')
plt.title('Distribution of Cholesterol')
plt.show()

# %%
sex_counts = data['Sex'].value_counts()
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%')
plt.legend(["Male", "Female"])  # Set the labels for the pie chart
plt.title('Proportion of Males and Females')
# Out:
# Text(0.5, 1.0, 'Proportion of Males and Females')

# %%
chest_pain_counts = data['ChestPainType'].value_counts()

# Create a bar plot of the 'ChestPainType' column
plt.bar(chest_pain_counts.index, chest_pain_counts.values)

# Set labels and title
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.title('Distribution of Chest Pain Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Chest Pain Types')

# %%
sns.countplot(x="HeartDisease", data = data)
plt.title('Distribution of Heart Disease')
plt.show()

# %%
# The majority of the Patient have Heart Disease. The class dont have class imbalance problem.

# %%
sns.displot(data, x="Age")
plt.title('Age Distribution')
plt.show()

# %%
# We can also confirm from above plot, that the majority of patient lies between 52-60 Years Age

# %%
sns.displot(data, x="Age", hue = 'HeartDisease')
plt.title('Age and Heart Disease')
plt.legend([ "Have Heart Disease", "Normal"])
plt.show()

# %%
# We can see that from graph majority of the patient with Heart Disease are aged and lies between 55 - 75.
# The patients with Normal Heart Condition lies betwen age 30 to 45
# There is a fine line between people with Heat Disease and Normal

# %%
 sns.countplot(x="Sex", data = data)
plt.title('Distribution of Sex Feature')

plt.show()

# %%
# The Majority of the population is the MALE.

# %%
# Now we will look at the Distribution of Male and Female with respect to Heart Disease and Normal Patients

# %%
sns.countplot(x="Sex", hue='HeartDisease', data=data)
plt.title('Sex vs Heart Disease')
plt.legend(["Normal", "Have Heart Disease"])  # Set the labels for the legend
plt.show()

# %%
# We can see from above graph, The majority of the males have Heart Disease
# In case of Females, the heart disease ratio is low.

# %% [markdown]
# Chest Pain
# This feature represents the type of chest pain patient diagnose with. The possible types in our data are:
#
# TA: Typical Angina (Typical angina (TA) is defined as substernal chest pain precipitated by physical
#     exertion or emotional stress and relieved with rest or nitroglycerin.)
# ATA: Atypical Angina (When one experiences chest pain that doesn't meet the criteria for angina,
#     it's known as atypical chest pain.)
# NAP: Non-Anginal Pain (Noncardiac chest pain is defined as recurring pain in your chest — typically,
#     behind your breast bone and near your heart — that is not related to your heart.
#     In most people, noncardiac chest pain is actually related to a problem with their esophagus,
#     most often gastroesophageal reflux disease (GERD)
#
# ASY: Asymptomatic (Silent (asymptomatic) myocardial ischemia (SMI) is defined as a transient alteration in
#     myocardial perfusion in the absence of chest pain or the usual anginal equivalents.)

# %%
sns.countplot(x="ChestPainType", hue = 'HeartDisease', data = data)
plt.title('Chest Pain and Heart Disease Relationship')
plt.legend(["Normal", "Have Heart Disease"])
plt.show()

# %%
# From the plot we can see that the patinets with Asymptomatic Chest Pain (ASY) are more likely to get the Heart Failure.
# The patients with typical Angina are also at high risk of Heart Failure.

# %%
sns.displot(data, x="RestingBP", hue='HeartDisease', kind = 'kde' )
plt.title('Resting Blood Pressure and Heart Disease Relationship')
plt.legend(["Have Heart Disease","Normal"])
plt.show()

# %%
# We can see that from graph, The trend of Normal People and People with Heart Disease is the same.

# %%
sns.displot(data, x="Cholesterol", hue='HeartDisease', kind = 'kde' )
plt.title('Cholesterol Level and Heart Disease Relationship')
plt.show()

# %%
# What is the trend of Fasting Blood Sugar?
# If blood sugar is greater than 120 md/dl, then the fasting sugar considered as high and assigned with 1 value in data.
# If the Sugar is below 120 it is considered as normal and assigned with 0 value in data.

# %%
sns.countplot( x="FastingBS", hue='HeartDisease', data =data )
plt.title('Cholesterol Level and Heart Disease Relationship')
plt.show()

# %%
# What is Resting ECG?
# Normal: Normal
# ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria

# %%
sns.countplot( x="RestingECG", hue='HeartDisease', data =data )
plt.title('Resting ECG and Heart Disease Relationship')
plt.show()

# %% [markdown]
# From the above plot of ECG, We can say that ECG is very important feature for us. As the ECG result are "ST" or "LVH",
#      there is high chance of heart Failure.
# We can also see that the people with Normal ECG also get Heart Disease, which means people can also get heart
#    disease with normal ECG, as it changes suddenly with heart conditions.

# %% [markdown]
# What is Trend of Maximum Heart Rate?
# MaxHR means Maximum Heart Rate Achieved. It contains Nuemeric values between 60 and 202

# %%
sns.displot(data, x="MaxHR", hue='HeartDisease', kind = 'kde' )
plt.title('Maximum Heart Rate vs Heart Disease Relationship')
plt.show()

# %% [markdown]
# What is the trend of Exercise Angina?
# Angina (pronounced ANN-juh-nuh or ann-JIE-nuh) is pain in the chest that comes on with exercise, stress, or other things that make the heart work harder. It is an extremely common symptom of coronary artery disease, which is caused by cholesterol-clogged coronary arteries.
#
# The Exercise-Induced Angina contains values as [Y: Yes, N: No]

# %%
sns.displot(data, x="ExerciseAngina", hue='HeartDisease')
plt.title('Exercise Angina and Heart Disease Relationship')
plt.show()

# %% [markdown]
#  We can see that from the Graph, the People with Exercise Angina is more likely to get the Heart Disease/Heart Failure.
#
#  This mean the patients have coronary artery disease

# %%
sns.displot(data, x="Oldpeak", hue='HeartDisease', kind = 'kde')
plt.title('Old Peak vs Heart Disease Relationship')
plt.show()

# %% [markdown]
# From the above plot we can see that if the value of Oldpeal is lower then equals to 0, there is less chance of Heart Disease and Heart Failure.
# From the plot, we can also see that if the value of old peak is greater than 0 there is high chance of Heart Disease

# %% [markdown]
# What is ST Slope?
# The ST segment shift relative to exercise-induced increments in heart rate, the ST/heart rate slope (ST/HR slope), has been proposed as a more accurate ECG criterion for diagnosing significant coronary artery disease (CAD).
#
# The Slope of the Peak Exercise ST Segment:
#
# Up: upsloping
# Flat: flat
# Down: downsloping

# %%
sns.countplot( x="ST_Slope", hue='HeartDisease', data =data )
plt.title('ST Slope and Heart Disease Relationship')
plt.show()

# %% [markdown]
# We can see from the above plot, if the slope gone flat and Down, there is high liklyhood of Heart Disease

# %% [markdown]
# # Correlation of Analysis

# %%
data[['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']].corr()
# Out:
#                   Age  RestingBP  Cholesterol     MaxHR   Oldpeak
# Age          1.000000   0.263570     0.010053 -0.393473  0.256797
# RestingBP    0.263570   1.000000     0.088392 -0.094786  0.155588
# Cholesterol  0.010053   0.088392     1.000000  0.090858  0.048835
# MaxHR       -0.393473  -0.094786     0.090858  1.000000 -0.181740
# Oldpeak      0.256797   0.155588     0.048835 -0.181740  1.000000

# %% [markdown]
# # Data Encoding

# %%
# Categorical Features
cat_features = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
Numeric_features = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in cat_features:
    data[i]=le.fit_transform(data[i])

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140        289.0          0           1
# 1   49    0              2        160        180.0          0           1
# 2   37    1              1        130        283.0          0           2
# 3   48    0              0        138        214.0          0           1
# 4   54    1              2        150        195.0          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
x = data.drop("HeartDisease", axis=1)
y = data["HeartDisease"]

# %%
x.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140        289.0          0           1
# 1   49    0              2        160        180.0          0           1
# 2   37    1              1        130        283.0          0           2
# 3   48    0              0        138        214.0          0           1
# 4   54    1              2        150        195.0          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 0    172               0      0.0         2
# 1    156               0      1.0         1
# 2     98               0      0.0         2
# 3    108               1      1.5         1
# 4    122               0      0.0         2

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: HeartDisease, dtype: int64

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
scaled_data = sc.fit_transform(x)

# %%
scaled_data
# Out:
# array([[-1.40126994,  0.51449576,  0.21744928, ..., -0.79880864,
#         -0.85673653,  1.03164229],
#        [-0.4506319 , -1.94365063,  1.26804692, ..., -0.79880864,
#          0.18584648, -0.65507324],
#        [-1.71814928,  0.51449576,  0.21744928, ..., -0.79880864,
#         -0.85673653,  1.03164229],
#        ...,
#        [ 0.39437968,  0.51449576, -0.83314836, ...,  1.25186428,
#          0.39436309, -0.65507324],
#        [ 0.39437968, -1.94365063,  0.21744928, ..., -0.79880864,
#         -0.85673653, -0.65507324],
#        [-1.61252283,  0.51449576,  1.26804692, ..., -0.79880864,
#         -0.85673653,  1.03164229]])

# %%
scaled_data.shape
# Out:
# (860, 11)

# %%
sns.boxplot(data=scaled_data) # no need this
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=4)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=4)

# %%
x_pca = pca.transform(scaled_data)

# %%
x_pca
# Out:
# array([[-2.11364248,  0.55390081, -0.31913438, -0.74323078],
#        [-1.00543092,  0.74074614,  1.55995719,  0.07717962],
#        [-0.96942429, -1.03712741, -0.41849014, -2.038347  ],
#        ...,
#        [ 1.74981773, -0.82572565, -0.66860838, -0.0405729 ],
#        [-1.62144552,  1.63576736,  0.20953297,  0.84284834],
#        [-2.46541021, -0.9942657 ,  0.23739064,  0.3437589 ]])

# %%
x_pca.shape
# Out:
# (860, 4)

# %%
sns.boxplot(data=x_pca) # no need this
# Out:
# <Axes: >

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(scaled_data,y,test_size=0.25,random_state=35)

# %%
x_train.shape,y_train.shape, x_test.shape, y_test.shape
# Out:
# ((645, 11), (645,), (215, 11), (215,))

# %% [markdown]
# # Machine Learning Modeling

# %%
# LogisticRegression

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score, roc_auc_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_logistic = LogisticRegression()

# %%
model_logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_logistic=model_logistic.predict(x_test)

# %%
logistic_acc = accuracy_score (y_test,y_pred_logistic)
logistic_acc
# Out:
# 0.8325581395348837

# %%
"""train_pred_logistic = model_logistic.predict(x_train)
accuracy_score(y_train, train_pred_logistic)"""
# Out:
# 'train_pred_logistic = model_logistic.predict(x_train)\naccuracy_score(y_train, train_pred_logistic)'

# %%
# svm - support vector machine

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC()

# %%
model_svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred_svm = model_svm.predict(x_test)

# %%
svm_acc = accuracy_score(y_test,y_pred_svm)
svm_acc
# Out:
# 0.8465116279069768

# %%
model_svm.score
# Out:
# <bound method ClassifierMixin.score of SVC()>

# %%
# KNN - K Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = model_knn.predict(x_test)

# %%
knn_acc = accuracy_score(y_test,y_pred_knn)
knn_acc
# Out:
# 0.8511627906976744

# %%
# DTC - Descision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dtc = DecisionTreeClassifier()

# %%
model_dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtc = model_dtc.predict(x_test)

# %%
dtc_acc= accuracy_score(y_test,y_pred_dtc)
dtc_acc
# Out:
# 0.786046511627907

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_random_forest = RandomForestClassifier()

# %%
model_random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_random_forest = model_random_forest.predict(x_test)

# %%
random_forest_acc = accuracy_score(y_test,y_pred_random_forest)
random_forest_acc
# Out:
# 0.8558139534883721

# %%
from sklearn.ensemble import VotingClassifier

# %%
model_ensemble = VotingClassifier(estimators=[
    ('dt', model_dtc),
    ('rf', model_random_forest),
    ('lr', model_logistic)
], voting='hard')

# %%
model_ensemble.fit(x_train, y_train)
# Out:
# VotingClassifier(estimators=[('dt', DecisionTreeClassifier()),
#                              ('rf', RandomForestClassifier()),
#                              ('lr', LogisticRegression())])

# %%
y_pred_ensemble = model_ensemble.predict(x_test)

# %%
ensemble_acc = accuracy_score(y_test,y_pred_ensemble)

# %%
ensemble_acc
# Out:
# 0.8651162790697674

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search = GridSearchCV(estimator=model_random_forest, param_grid=parameters, scoring='accuracy', cv=5)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
best_model_grid_search = grid_search.best_estimator_
accuracy = best_model_grid_search.score(x_test, y_test)

# %%
print("Best Parameters:", best_params)
print("Best Score:", best_score)
print("Accuracy:", accuracy)
# Out:
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score: 0.875968992248062
# Accuracy: 0.827906976744186

# %% [markdown]
# # Plotting Accuracy of different ML Algorithm

# %%
plt.figure(figsize=(11,5))
plt.bar("LogisticRegression",logistic_acc,width=0.4)
plt.bar("Support Vector Machine",svm_acc,width=0.4)
plt.bar("K Nearest Neighbour",knn_acc,width=0.4)
plt.bar("DecisionTreeClassifier",dtc_acc,width=0.4)
plt.bar("RandomForestClassifier",random_forest_acc,width=0.4)
plt.xlabel("Machine Learning Algorithm")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Single Prediction

# %%
result = model_svm.predict(sc.transform([[50,0,0,105,250,1,2,175,1,1.9,0]]))

if result==[0]:
    print("Person doesn't have Heart Disease")
else:
    print("Person have Heart Disease")
# Out:
# Person have Heart Disease
# C:\Users\SAURABH\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
result = model_svm.predict(sc.transform([[30,0,1,140,290,0,0,160,1,1,1]]))

if result==[0]:
    print("Person doesn't have Heart Disease")
else:
    print("Person have Heart Disease")
# Out:
# Person doesn't have Heart Disease
# C:\Users\SAURABH\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# if the accuracy is not increasing the we have to put this model in neural network
